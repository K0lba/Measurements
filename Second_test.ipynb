# %% [markdown]
# __Гистограмма__:
# <p align="center">
#     <img src="images/Figure_2.png" alt="тут должна быть гистограмма">
# </p>
#
# __P-value__:
# $0.097$
#
# __Среднее__:
# $0.48$
#
# __Стандартное отклонение__:
# $0.0042$
#
# __Стандартное отклонение среднего__:
# $0.00066$
#
# __Предсказывающий интервал__:
# $[0.4734..0.4902]$
#
# __Доверительный интервал__:
# $[0.4805..0.4832]$
#
# __Погрешность__:
# $0.00135$
